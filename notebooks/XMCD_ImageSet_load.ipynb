# %% [markdown]
# # How to load ImageSets
# In this notebook we will create and save ImageSets into .nxs file
#
# ## Load libraries

# %%
from data_structure import ImageSet

# %% [markdown]
# ## Now we will define paths to our data
#
# We will load one .nxs file containing our 4 images.

# %%
path = 'results/xmcd_images.nxs'

# %% [markdown]
# # Definition of ImageSets

# %%
positive_imageset = ImageSet(type_measurement="xmcd")
negative_imageset = ImageSet(type_measurement="xmcd")

# %% [markdown]
# # We will firstly explore the content of our .nxs file

# %%
positive_imageset.show_content(path)
# Out:
# {'xmcd_0': NXentry('xmcd_0'), 'xmcd_1': NXentry('xmcd_1')}

# %% [markdown]
# # Now we will load our images according to its id_numer

# %%
positive_imageset.load_ImageSet(path,id_number=0)
negative_imageset.load_ImageSet(path,id_number=1)
# Out:
# xmcd_0:NXentry
#   @default = 'raw_images'
#   metadata:NXdata
#     metadata = '{'_HyperSpy': {'Folding': {'unfolded': False, 'signal_un...'
#     original_metadata = '{"ImageWidth": 984, "ImageLength": 974, "BitsPerSample":...'
#   raw_images:NXdata
#     image = uint16(974x984)
#       @interpretation = 'image'
#       @signal = 'image'
#       @units = 'pixesl'
# xmcd_1:NXentry
#   @default = 'raw_images'
#   metadata:NXdata
#     metadata = '{'_HyperSpy': {'Folding': {'unfolded': False, 'signal_un...'
#     original_metadata = '{"ImageWidth": 984, "ImageLength": 974, "BitsPerSample":...'
#   raw_images:NXdata
#     image = uint16(974x984)
#       @interpretation = 'image'
#       @signal = 'image'
#       @units = 'pixesl'

# %%
positive_imageset.image.plot()

# %%
negative_imageset.image.original_metadata
# Out:
# ├── BitsPerSample = 16
# ├── Compression = 1
# ├── ImageLength = 974
# ├── ImageWidth = 984
# ├── Orientation = 4
# ├── PhotometricInterpretation = 1
# ├── PlanarConfiguration = 1
# ├── RowsPerStrip = 974
# ├── SampleFormat = 1
# ├── SamplesPerPixel = 1
# ├── StripByteCounts = [1916832]
# └── StripOffsets = [8]

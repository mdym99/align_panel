# %% [markdown]
# # How to load ImageSets
# In this notebook we will create and save ImageSets into .nxs file
#
# ## Load libraries

# %%
from data_structure import ImageSet

# %% [markdown]
# ## Now we will define paths to our data
#
# We will load one .nxs file containing our 4 images.

# %%
path = 'results/holograpy_images.nxs'

# %% [markdown]
# # Definition of ImageSets

# %%
positive_imageset = ImageSet(type_measurement="holography")
negative_imageset = ImageSet(type_measurement="holography")

# %% [markdown]
# # We will firstly explore the content of our .nxs file

# %%
positive_imageset.show_content(path, scope='short')
# Out:
# {'holography_0': NXentry('holography_0'), 'holography_1': NXentry('holography_1')}

# %% [markdown]
# # Now we will load our images according to its id_numer

# %%
positive_imageset.load_ImageSet(path,id_number=0)
negative_imageset.load_ImageSet(path,id_number=1)
# Out:
# holography_0:NXentry
#   @default = 'raw_images'
#   metadata:NXdata
#     metadata = '{'_HyperSpy': {'Folding': {'unfolded': False, 'signal_un...'
#     original_metadata = '{'root': {}, 'ApplicationBounds': (0, 0, 1503, 2971), 'D...'
#     ref_metadata = '{'_HyperSpy': {'Folding': {'unfolded': False, 'signal_un...'
#     ref_original_metadata = '{'root': {}, 'ApplicationBounds': (0, 0, 1503, 2971), 'D...'
#   raw_images:NXdata
#     image = float32(4092x5760)
#       @interpretation = 'image'
#       @signal = 'image'
#       @units = 'pixesl'
#     ref_image = float32(4092x5760)
#       @units = 'pixesl'
# holography_1:NXentry
#   @default = 'raw_images'
#   metadata:NXdata
#     metadata = '{'_HyperSpy': {'Folding': {'unfolded': False, 'signal_un...'
#     original_metadata = '{'root': {}, 'ApplicationBounds': (0, 0, 1503, 2971), 'D...'
#     ref_metadata = '{'_HyperSpy': {'Folding': {'unfolded': False, 'signal_un...'
#     ref_original_metadata = '{'root': {}, 'ApplicationBounds': (0, 0, 1503, 2971), 'D...'
#   raw_images:NXdata
#     image = float32(4092x5760)
#       @interpretation = 'image'
#       @signal = 'image'
#       @units = 'pixesl'
#     ref_image = float32(4092x5760)
#       @units = 'pixesl'

# %%
positive_imageset.image.plot()

# %%
negative_imageset.image.metadata
# Out:
# ├── Acquisition_instrument
# │   └── TEM
# │       ├── Camera
# │       │   └── exposure = 0.09984000249600006
# │       ├── acquisition_mode = TEM
# │       ├── beam_current = 0.0
# │       ├── beam_energy = 300.0
# │       ├── magnification = 500000.0
# │       └── microscope = Hitachi HF3300 v1.06
# ├── General
# │   ├── FileIO
# │   │   └── 0
# │   │       ├── hyperspy_version = 1.7.3
# │   │       ├── io_plugin = hyperspy.io_plugins.digital_micrograph
# │   │       ├── operation = load
# │   │       └── timestamp = 2023-03-29T09:35:38.978009+02:00
# │   ├── date = 2023-02-08
# │   ├── original_filename = Z1_H.dm4
# │   ├── time = 11:39:14
# │   └── title = Z1_H
# └── Signal
#     ├── Noise_properties
#     │   └── Variance_linear_model
#     │       ├── gain_factor = 1.0
#     │       └── gain_offset = 0.0
#     ├── quantity = Intensity
#     └── signal_type = hologram
